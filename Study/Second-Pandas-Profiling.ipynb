# %%
#! pip install pandas==0.25

# %%
# 좋은 머신러닝의 결과를 얻기 위해서는 데이터의 성격을 파악하는 과정이 선행 되어야 함.
# pip install -U pandas-profiling
#-*-coding:utf-8-*-
import pandas as pd
import pandas_profiling
#!ls /content/sample_data/
csv_file_train = './datas/spam.csv'
#csv_file_test = '/content/sample_data/california_housing_test.csv'
datas = pd.read_csv(csv_file_train, encoding='latin1')
#ch_test_df = pd.read_csv(csv_file_test)

print(datas.head())
#print(ch_test_df.head())
# Out:
# v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
pr = datas.profile_report()
pr.to_file('./pr_files/spam.html')
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 143.23it/s]
